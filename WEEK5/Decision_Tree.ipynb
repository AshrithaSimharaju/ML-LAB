# %%
#Import the Necessary Libraries
import pandas as pd
df=pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Look at top values of train data 
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Print the column names of train data
print(list(df.columns))
# Out:
# ['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'FamilySize', 'IsAlone', 'Has_cabin']

# %%
#Print the dimension of train and test data
df.shape
# Out:
# (891, 11)

# %%
#Print the number of missing values in each column of train and test data
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Embarked      0
# FamilySize    0
# IsAlone       0
# Has_cabin     0
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
#Barchart of Survived, Pclass, Sex, Embarked
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,6))
# plt.subplot(2,2,1)
sns.countplot(x=df['Survived'],hue=df['Survived'],legend=True,palette="coolwarm")
plt.title("survival")
plt.show()

plt.figure(figsize=(12,6))
# plt.subplot(2,2,2)
sns.countplot(x=df['Pclass'],hue=df['Pclass'],palette="coolwarm",legend=True)
plt.title("Pclass")
plt.show()

plt.figure(figsize=(12,6))
sns.countplot(x=df['Sex'],hue=df['Sex'],legend=True,palette="Set1")
plt.title("Sex")
plt.show()

plt.figure(figsize=(12,6))
sns.countplot(x=df['Embarked'],hue=df["Embarked"],legend=True,palette="Set2")
plt.title("Embarked")
plt.show()

# %%
#Histogram of Age, Parch, Fare
column=['Age','Parch','Fare']
color=['red','green','orange']
for c,col in zip(color,column):
    plt.figure(figsize=(12,6))
    sns.histplot(df[col].dropna(),bins=10,kde=True,color=c)
    plt.show()

# %%
#Plot histogram of age for survived and did not survived class
plt.figure(figsize=(12,6))
sns.histplot(df[df['Survived']==1]['Age'].dropna(),kde=True,bins=10,color="violet")
plt.show()

plt.figure(figsize=(12,6))
sns.histplot(df[df["Survived"]==0]['Age'].dropna(),kde=True,bins=10,color="orange")
plt.show()

# %%
#Count class and geder wise survival rate - plot with appropriate chart

survival_rates=df.groupby(["Pclass","Sex"])['Survived'].mean().reset_index()
print(survival_rates)
# Out:
#    Pclass     Sex  Survived
# 0       1  female  0.968085
# 1       1    male  0.368852
# 2       2  female  0.921053
# 3       2    male  0.157407
# 4       3  female  0.500000
# 5       3    male  0.135447

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=survival_rates,x="Pclass",y="Survived",hue="Sex",palette="Set2")
plt.legend(title='Gender')
plt.show()

# %%
#Age wise Distribution of Male and Female passengers
plt.figure(figsize=(12,6))
sns.histplot(df[df["Sex"]=='male']["Age"].dropna(),bins=20,kde=True,color="orange")
sns.histplot(df[df["Sex"]=='female']["Age"].dropna(),bins=20,kde=True,color="red")
plt.show()

# %%
#Histogram of Age of the given data set(sample)
plt.figure(figsize=(12,6))
sns.histplot(df['Age'].dropna(),kde=True,bins=20,color='pink')
plt.xlabel("Age")
plt.ylabel("count")
plt.title("Age disribution")
plt.show()

# %% [markdown]
# # Handling Missing Values

# %%
#Replace the msiing values in Embarked column by 'S'
df['Embarked'].fillna('S',inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
#Inpute the missing values in Fare column with median value
df['Fare'].fillna(df['Fare'].median(),inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
#Impute the Age column. It has too many missing values but it may be important. 
#We fill the missing values with numbers randomly drawn from distribution
#that has same mean and standard deviation as non missing Age data
import numpy as np
mean=df["Age"].mean()
std=df["Age"].std()
random_val=np.random.normal(mean,std,size=df["Age"].isnull().sum())
df.loc[df["Age"].isnull(),"Age"]=random_val
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# # Feature Engineering - CReating new features

# %%
# Create and add a new feature FamilySize as a combination of SibSp and Parch
#FamilySize = Parch + SibSp + 1
df['FamilySize']=df['Parch']+df['SibSp']+1
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
# Create new feature IsAlone from FamilySize
#If FamilySize == 1 then IsAlone = True else IsAlone = False
df['IsAlone']=df['FamilySize']==1
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df["Has_cabin"]=df["Cabin"].notna()
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# # Create a new attribute Has_cabin using the attribute Cabin

# %%
#Drop the columns which may not be useful in prediction of survival
#Drop PassengerId, Name, Ticket, and Cabin
df=df.drop(columns=["PassengerId","Name","Ticket","Cabin"])
df
# Out:
#      Survived  Pclass     Sex        Age  SibSp  Parch     Fare Embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female   6.521185      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#      FamilySize  IsAlone  Has_cabin
# 0             2    False      False
# ...

# %% [markdown]
# # Model Building

# %%
#Prepare X and y
X=df.drop(columns=['Survived'])
y=df['Survived']

# %%
print(X.shape)
print(y.shape)
# Out:
# (891, 10)
# (891,)

# %%
# Label encoding of categorical features
from sklearn.preprocessing import LabelEncoder
columns=X.select_dtypes(include=['object','bool']).columns
le=LabelEncoder()
for col in columns:
    X[col]=le.fit_transform(X[col])
X
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked  FamilySize  \
# 0         3    1  22.000000      1      0   7.2500         2           2
# 1         1    0  38.000000      1      0  71.2833         0           2
# 2         3    0  26.000000      0      0   7.9250         2           1
# 3         1    0  35.000000      1      0  53.1000         2           2
# 4         3    1  35.000000      0      0   8.0500         2           1
# ..      ...  ...        ...    ...    ...      ...       ...         ...
# 886       2    1  27.000000      0      0  13.0000         2           1
# 887       1    0  19.000000      0      0  30.0000         2           1
# 888       3    0   6.521185      1      2  23.4500         2           4
# 889       1    1  26.000000      0      0  30.0000         0           1
# 890       3    1  32.000000      0      0   7.7500         1           1
#
#      IsAlone  Has_cabin
# 0          0          0
# 1          0          1
# ...

# %%
# concat df_categorical with original df
df1=pd.read_csv("train.csv")
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df_categorical=X[["Sex","Embarked","IsAlone","Has_cabin"]]
df_numerical=df.drop(columns=["Sex","Embarked","IsAlone","Has_cabin"],axis=1)
df1=pd.concat([df_categorical,df_numerical],axis=1)
df1
# Out:
#      Sex  Embarked  IsAlone  Has_cabin  Survived  Pclass        Age  SibSp  \
# 0      1         2        0          0         0       3  22.000000      1
# 1      0         0        0          1         1       1  38.000000      1
# 2      0         2        1          0         1       3  26.000000      0
# 3      0         2        0          1         1       1  35.000000      1
# 4      1         2        1          0         0       3  35.000000      0
# ..   ...       ...      ...        ...       ...     ...        ...    ...
# 886    1         2        1          0         0       2  27.000000      0
# 887    0         2        1          1         1       1  19.000000      0
# 888    0         2        0          0         0       3   6.521185      1
# 889    1         0        1          1         1       1  26.000000      0
# 890    1         1        1          0         0       3  32.000000      0
#
#      Parch     Fare  FamilySize
# 0        0   7.2500           2
# ...

# %%
# #Do a pairplot of all features
sns.pairplot(df)
plt.show()

# %%
# sns.pairplot(df1.select_dtypes(include=["number"]))
# plt.show()

# %%
# Splitting the data into train and validation set - 90% train 10% validation
#X_train, X_test, y_train, y_validation
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (801, 10)
# (90, 10)
# (801,)
# (90,)

# %%
# Create the model
# Fitting the decision tree with default hyperparameters
# Importing decision tree classifier from sklearn library
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(criterion="entropy",random_state=42)
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
#Print the tree
#Importing required packages for visualization

# %%
from sklearn import tree
plt.figure(figsize=(12,8))
tree.plot_tree(model,feature_names=X.columns,class_names=['Survived','Not Suvived'],filled=True,precision=2,fontsize=13,max_depth=2)
plt.show()

# %%
# Check the evaluation metrics of our default model on validation set - Confusion Matrix, Accuracy, Precision, Recall, F1 score

# Importing classification report and confusion matrix from sklearn metrics

# Making predictions

# Printing classification report
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# Make sure you're predicting on the features (X_test), not labels (y_test)
y_pred = model.predict(X_test)

# Confusion Matrix
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Classification Report
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))

# Precision
print("Precision:", precision_score(y_test, y_pred))

# Recall
print("Recall:", recall_score(y_test, y_pred))

# F1 Score
print("F1 Score:", f1_score(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[40 14]
#  [ 5 31]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.74      0.81        54
#            1       0.69      0.86      0.77        36
#
#     accuracy                           0.79        90
#    macro avg       0.79      0.80      0.79        90
# weighted avg       0.81      0.79      0.79        90
#
# Accuracy: 0.7888888888888889
# Precision: 0.6888888888888889
# Recall: 0.8611111111111112
# F1 Score: 0.7654320987654321
